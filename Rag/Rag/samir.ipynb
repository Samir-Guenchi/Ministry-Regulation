# %%
# !pip install google.generativeai
# Out:
# ...
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/1.3 MB ? eta -:--:--
#    ------- -------------------------------- 0.3/1.3 MB ? eta -:--:--
#    --------------- ------------------------ 0.5/1.3 MB 1.7 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.3 MB 1.8 MB/s eta 0:00:01
#    ----------------------- ---------------- 0.8/1.3 MB 1.8 MB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.3 MB 986.7 kB/s eta 0:00:01
#    ------------------------------- -------- 1.0/1.3 MB 986.7 kB/s eta 0:00:01
#    ---------------------------------------- 1.3/1.3 MB 811.3 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/13.3 MB ? eta -:--:--
#     --------------------------------------- 0.3/13.3 MB ? eta -:--:--
#    - -------------------------------------- 0.5/13.3 MB 1.0 MB/s eta 0:00:13
# ...
